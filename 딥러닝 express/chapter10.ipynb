# %% [markdown]
# 코드 셀 : 명령어 작성
#
# 마크다운 셀 : 설명 작성
#
#
# shift + enter : 셀이 추가되고 실행
#
# ctrl + enter : 셀이 추가되지 않고 실행
#
#
# - A : 위쪽에 셀 추가
# - B : 아래쪽에 셀 추가
# - D,D : 셀 삭제
# - Y : 셀을 코드로 변경
# - M : 셀을 마크다운으로 변경

# %%
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import *

(X_train,y_train),(X_test,y_test) = keras.datasets.cifar10.load_data()

plt.figure()
plt.imshow(X_train[1])
plt.colorbar()

X_train = X_train/255.0
X_test = X_test/255.0

model = Sequential()
model.add(Conv2D(64,activation='relu',kernel_size=(3,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32,activation='relu',kernel_size=(3,3)))
model.add(Flatten(input_shape=(32,32,3)))
model.add(Dense(80,activation='relu'))
model.add(Dense(10,activation='softmax'))

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

history=model.fit(X_train,y_train,epochs=10,verbose=1,validation_split=0.3)
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020A2DE453A0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020A2DE453A0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1094/1094 [==============================] - ETA: 0s - loss: 1.5159 - accuracy: 0.4527WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020A29CF05E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unknown node type <gast.gast.Expr object at 0x0000020A2D4E30A0>
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000020A29CF05E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unknown node type <gast.gast.Expr object at 0x0000020A2D4E30A0>
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1094/1094 [==============================] - 29s 25ms/step - loss: 1.5159 - accuracy: 0.4527 - val_loss: 1.3464 - val_accuracy: 0.5215
# Epoch 2/10
# 1094/1094 [==============================] - 27s 25ms/step - loss: 1.1808 - accuracy: 0.5805 - val_loss: 1.1680 - val_accuracy: 0.5816
# Epoch 3/10
# 1094/1094 [==============================] - 27s 24ms/step - loss: 1.0371 - accuracy: 0.6376 - val_loss: 1.0574 - val_accuracy: 0.6314
# Epoch 4/10
# 1094/1094 [==============================] - 27s 24ms/step - loss: 0.9262 - accuracy: 0.6750 - val_loss: 1.0348 - val_accuracy: 0.6412
# Epoch 5/10
# 1094/1094 [==============================] - 27s 25ms/step - loss: 0.8388 - accuracy: 0.7054 - val_loss: 1.0064 - val_accuracy: 0.6491
# Epoch 6/10
# 1094/1094 [==============================] - 27s 25ms/step - loss: 0.7710 - accuracy: 0.7306 - val_loss: 1.0154 - val_accuracy: 0.6551
# Epoch 7/10
# 1094/1094 [==============================] - 27s 24ms/step - loss: 0.6964 - accuracy: 0.7567 - val_loss: 1.0583 - val_accuracy: 0.6471
# Epoch 8/10
# 1094/1094 [==============================] - 25s 23ms/step - loss: 0.6305 - accuracy: 0.7791 - val_loss: 1.0542 - val_accuracy: 0.6596
# Epoch 9/10
# 1094/1094 [==============================] - 25s 23ms/step - loss: 0.5659 - accuracy: 0.8009 - val_loss: 1.1138 - val_accuracy: 0.6451
# Epoch 10/10
# 1094/1094 [==============================] - 25s 23ms/step - loss: 0.5065 - accuracy: 0.8208 - val_loss: 1.1787 - val_accuracy: 0.6483

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss','val_loss'],loc='lower right')
plt.show

plt.figure()
plt.imshow(X_test[0])
y_pred = model.predict(X_test)
print("정답=",y_test[0])
print("예측값=",y_pred[0])
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020A2D49A0D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020A2D49A0D0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 313/313 [==============================] - 1s 4ms/step
# 정답= [3]
# 예측값= [4.3087194e-04 1.0707426e-04 4.9477248e-03 7.9543000e-01 2.0315424e-03
#  8.3839744e-03 1.7578451e-01 3.5143725e-03 8.7792269e-04 8.4918393e-03]
